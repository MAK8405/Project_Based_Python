# %% [markdown]
# A script = a file

# %% [markdown]
# # 📌 What “script” means in Python
#
# A **script** = a **Python file** (`.py`) that is meant to be **run directly** to *do something*.
#
# Think of it like:
#
# * A “recipe” you execute
# * A file that performs tasks step-by-step
# * Usually starts at line 1 and runs to the end
#
# Example:
#
# ```python
# print("Hello, world!")
# ```
#
# This is a **script**.
#
# ---
#
# # 📌 A Python file can be 3 different things
#
# ### 1️⃣ **Script**
#
# A file meant to *run*.
# Example: `main.py`, `run_bot.py`, `clean_data.py`
#
# ```python
# print("Running cleanup...")
# ```
#
# ---
#
# ### 2️⃣ **Module**
#
# A file meant to *be imported* by other Python files.
# Example: `utils.py`
#
# ```python
# def add(a, b):
#     return a + b
# ```
#
# You don’t *run* it directly; you import it:
#
# ```python
# import utils
# ```
#
# ---
#
# ### 3️⃣ **Package**
#
# A folder with an `__init__.py` file inside it.
#
# ```
# mypackage/
#     __init__.py
#     tools.py
#     models.py
# ```
#
# ---
#
# # 🎯 So… is a script a file?
#
# **Yes — all scripts are Python files.
# But not all Python files are scripts.**
#
# * `file.py` that you run ⇒ **script**
# * `file.py` that you import ⇒ **module**
#
# Very simple difference.
#
# ---
#
# # 🧠 Tiny memory hook for brain
#
# “Script” = **a file you *run***
# “Module” = **a file you *reuse***
#
# Run → Script
# Reuse → Module

# %% [markdown]
# first we create a folder named "src"
# our code will be in the "src folder", all the things is related to running the code.
#
# beside src we will have the README.md file next to it.
#
# README.md -> من را بخوان:
#
# - markdown format
# - explain our code
# - how to run
#
# a simple way to write it:
#
# - first we would have the title of the project: "# Number Guesser Game Project"
# - in it's dedicated
