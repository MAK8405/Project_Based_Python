# %% [markdown]
# # Quiz: Writing a `README.md` File

# %% [markdown]
# **1️⃣ What is the purpose of a README.md file?**
#
# a) It contains the project's code.
# b) It provides essential information about the project.
# c) It lists the names of project contributors.
# d) It serves as a backup of project files.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **It provides essential information about the project.**
#
# 💡 **Explanation:**
# A **README.md** file serves as a **documentation file** that provides important information about the project, such as its **purpose, setup instructions, and usage guidelines**.
#
# </details>

# %% [markdown]
# **2️⃣ Why is a well-crafted README.md file important for a project?**
#
# a) It helps users and contributors understand how to set up and use the project effectively.
# b) It provides instructions, usage examples, and other relevant details.
# c) It make the project more accessible and user-friendly.
# d) All of the above
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **All of the above**
#
# 💡 **Explanation:**
# A well-crafted **README.md** file helps users and contributors **understand how to set up and use the project effectively**. It provides **instructions, usage examples, and other relevant details**, making the project more **accessible and user-friendly**.
#
# </details>

# %% [markdown]
# **3️⃣ Where is a README.md file commonly found in GitHub repositories?**
#
# a) Inside the "src" directory.
# b) In the "assets" folder.
# c) In the root directory.
# d) Within the "tests" folder.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **In the root directory.**
#
# 💡 **Explanation:**
# In GitHub repositories, a **README.md** file is typically located in the **root directory**. It serves as the **entry point for users** and provides an **overview of the project**.
#
# </details>

# %% [markdown]
# **4️⃣ Which of the following sections are typically considered essential in a README.md file for a Python project? (Select all that apply)**
#
# a) Project Title
# b) Introduction
# c) Roadmap
# d) FAQ
# e) Prerequisites
# f) Screenshots
# g) API Reference
# h) Installation
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Project Title**, b) **Introduction**, e) **Prerequisites**, h) **Installation**
#
# 💡 **Explanation:**
# The essential sections in a **README.md** file for a Python project are:
#
# - **Project Title**
# - **Introduction**
# - **Prerequisites**
# - **Installation**
# - **Usage**
# - **Contributing**
# - **License**
#
# The other options are **not considered essential** sections in a README.md file for a Python project.
#
# </details>

# %% [markdown]
# **5️⃣ Which section of a README.md file provides a clear, step-by-step guide to set up the project?**
#
# a) Project Title
# b) Introduction
# c) Prerequisites
# d) Installation
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **Installation**
#
# 💡 **Explanation:**
# The **Installation** section of a **README.md** file provides **step-by-step instructions** to set up the project.
#
# </details>

# %% [markdown]
# **6️⃣ Which section of a README.md file explains what the project is about in a short paragraph?**
#
# a) Project Title
# b) Introduction
# c) Prerequisites
# d) Usage
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Introduction**
#
# 💡 **Explanation:**
# The **Introduction** section of a **README.md** file provides a **brief explanation** of what the project is about.
#
# </details>

# %% [markdown]
# **7️⃣ Which section of a README.md file lists the requirements or software that must be installed before running the project?**
#
# a) Project Title
# b) Introduction
# c) Prerequisites
# d) Installation
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Prerequisites**
#
# 💡 **Explanation:**
# The **Prerequisites** section of a **README.md** file lists any **preconditions or software** that must be installed before running the project.
#
# </details>

# %% [markdown]
# **8️⃣ Which section of a README.md file shows how to use the project with code snippets and examples?**
#
# a) Introduction
# b) Prerequisites
# c) Usage
# d) Contributing
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Usage**
#
# 💡 **Explanation:**
# The **Usage** section of a **README.md** file provides **code snippets and examples** to show how to use the project.
#
# </details>

# %% [markdown]
# **9️⃣ Which section of a README.md file explains how others can contribute to the project?**
#
# a) Usage
# b) Contributing
# c) License
# d) Features
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Contributing**
#
# 💡 **Explanation:**
# The **Contributing** section of a **README.md** file explains how others can **contribute to the project** and may include a **CONTRIBUTING.md** file.
#
# </details>

# %% [markdown]
# **🔟 Which section of a README.md file provides a list of features that the project offers?**
#
# a) Features
# b) Screenshots
# c) Tech Stack
# d) API Reference
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Features**
#
# 💡 **Explanation:**
# The **Features** section of a **README.md** file provides a **list of features** that the project offers.
#
# </details>

# %% [markdown]
# Q Checked ✅
# Answer Checked ✅
