# %% [markdown]
# # Quiz: VS Code Extensions

# %% [markdown]
# **1️⃣ What is the main purpose of the Material Theme extension for Visual Studio Code?**
#
# a) Providing code suggestions.
# b) Enhancing the version control system.
# c) Offering a modern and clean user interface.
# d) Automating code deployment.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Offering a modern and clean user interface.**
#
# 💡 **Explanation:**
# The Material Theme extension aims to enhance the visual appearance of Visual Studio Code by offering a modern and clean user interface, making it visually appealing.
#
# </details>

# %% [markdown]
# **2️⃣ What is the primary purpose of the Material Icon Theme extension for Visual Studio Code?**
#
# a) Automatically corrects code indentation.
# b) Provides code suggestions based on project icons.
# c) Converts code comments into visual icons for better comprehension.
# d) Adds a set of Material Design icons to complement the Material Theme.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **Adds a set of Material Design icons to complement the Material Theme.**
#
# 💡 **Explanation:**
# The Material Icon Theme extension in Visual Studio Code adds a set of Material Design icons that complement the Material Theme.
# These icons enhance the visual consistency and aesthetics of the theme, making it easier to identify files, folders, and elements in your project.
#
# </details>

# %% [markdown]
# **3️⃣ What does the Indent Rainbow extension do?**
#
# a) Colors the indentation levels in code
# b) Converts tabs to spaces in code.
# c) Highlights syntax errors in code.
# d) Generates random indentation patterns
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Colors the indentation levels in code**
#
# 💡 **Explanation:**
# The Indent Rainbow extension improves code readability by adding color to indentation levels,
# helping users quickly identify different code blocks based on their indentation.
#
# </details>

# %% [markdown]
# **4️⃣ Which extension generates random values and data for testing purposes?**
#
# a) Randomize All the Things
# b) Random Everything
# c) Data Generator Pro
# d) Test Data Magic
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Random Everything**
#
# 💡 **Explanation:**
# The Random Everything extension is a development utility that generates random values, strings, and data, which can be useful for populating code with sample data during testing and experimentation.
#
# </details>

# %% [markdown]
# **5️⃣ What is the primary function of the Toggle Quotes extension?**
#
# a) Automatically formats code indentation.
# b) Removes all single and double quotes within the code.
# c) Switches between different code languages.
# d) Simplifies the process of changing quotation styles.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **Simplifies the process of changing quotation styles.**
#
# 💡 **Explanation:**
# The Toggle Quotes extension simplifies the process of changing quotation styles by allowing users to easily switch between single and double quotes within their code.
#
# </details>

# %% [markdown]
# **6️⃣ How does the Better Comments extension enhance code readability?**
#
# a) Converts code comments into executable code.
# b) Converts comments to speech for accessibility.
# c) Provides customizable comment styles.
# d) Auto-generates comments based on code logic.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Provides customizable comment styles.**
#
# 💡 **Explanation:**
# The Better Comments extension enhances code comprehension by offering customizable comment styles that help different types of comments stand out, providing visual hierarchy to the code.
#
# </details>

# %% [markdown]
# **7️⃣ What purpose does the CodeSnap extension serve?**
#
# a) Automatically generates code documentation.
# b) Captures and shares code screenshots.
# c) Converts code to video format.
# d) Provides version control for code snapshots.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Captures and shares code screenshots.**
#
# 💡 **Explanation:**
# The CodeSnap extension allows users to capture and share screenshots of their code, making it convenient for creating quick code snapshots for documentation or sharing.
#
# </details>

# %% [markdown]
# **8️⃣ Which extension highlights TODO comments in code?**
#
# a) Comment Tracker
# b) Code Tasker
# c) Task Highlighter
# d) TODO Highlight
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **TODO Highlight**
#
# 💡 **Explanation:**
# The TODO Highlight extension highlights "TODO" comments in code, making it easier to identify and keep track of tasks and improvements directly within the codebase.
#
# </details>

# %% [markdown]
# **9️⃣ What does the Todo Tree extension do?**
#
# a) Generates a tree-based code structure.
# b) Displays all code comments as a tree view.
# c) Organizes tasks and "TODO" comments in a tree view.
# d) Converts code into an outline format.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Organizes tasks and "TODO" comments in a tree view.**
#
# 💡 **Explanation:**
# The Todo Tree extension organizes and manages tasks across a codebase by displaying "TODO" comments and tasks in a tree view, aiding in task organization.
#
# </details>

# %% [markdown]
# **1️⃣0️⃣ Which extension helps manage multiple projects and their files?**
#
# a) Project Manager
# b) Multi-Project Organizer
# c) File Management Suite
# d) Task and Project Tracker
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Project Manager**
#
# 💡 **Explanation:**
# The Project Manager extension simplifies the management of multiple projects and their associated files, making it easier to switch between different project contexts.
#
# </details>
