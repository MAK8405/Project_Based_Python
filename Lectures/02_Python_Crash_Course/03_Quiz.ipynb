# %% [markdown]
# # Quiz: Troubleshooting and Tips

# %% [markdown]
# **1️⃣ What is the primary purpose of using `print()` function for debugging in Python?**
#
# a) To hide errors from users.
# b) To display messages to users.
# c) To track the flow of execution and check variable values.
# d) `print()` function is not useful for debugging.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **To track the flow of execution and check variable values.**
#
# 💡 **Explanation:**
# The `print()` function helps you understand how your code is being executed
# and allows you to monitor the values of variables at different points in your program.
#
# </details>

# %% [markdown]
# **2️⃣ What should you do when encountering a syntax error in your Python code?**
#
# a) Ignore it, as it will not affect the program's execution.
# b) Carefully review your code for typographical errors and incorrect syntax.
# c) Continue coding without addressing it.
# d) Remove all comments to resolve the error.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Carefully review your code for typographical errors and incorrect syntax.**
#
# 💡 **Explanation:**
# Syntax errors are caused by incorrect Python syntax, such as missing colons, parentheses, or other punctuation marks.
# Reviewing your code for such errors is essential.
#
# </details>

# %% [markdown]
# **3️⃣ What is the purpose of updating your Python installation and libraries?**
#
# a) Updates include bug fixes, new features, and performance improvements.
# b) Updates help you hide errors in your code.
# c) Updates only improve the speed of your code.
# d) Updates only affect the appearance of your code.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Updates include bug fixes, new features, and performance improvements.**
#
# 💡 **Explanation:**
# Regularly updating your Python installation and libraries ensures that you have access to the latest bug fixes, features, and optimizations.
#
# </details>

# %% [markdown]
# **4️⃣ What is the recommended approach for seeking help when facing a challenging coding problem?**
#
# a) Keep the problem to yourself and try to solve it on your own.
# b) Consult unrelated sources to gather more information.
# c) Seek help from online forums, developer communities, or platforms like Stack Overflow.
# d) Rely only on the official Python documentation.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Seek help from online forums, developer communities, or platforms like Stack Overflow.**
#
# 💡 **Explanation:**
# The Python community is supportive and can provide valuable insights and solutions to your coding challenges.
# You can seek help from online forums, developer communities, or platforms like Stack Overflow.
#
# </details>

# %% [markdown]
# **5️⃣ What can you learn from carefully reading error messages in Python?**
#
# a) How to suppress error messages.
# b) The exact line number where the error occurred.
# c) Error messages are irrelevant and can be ignored.
# d) Error messages provide no useful information.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **The exact line number where the error occurred.**
#
# 💡 **Explanation:**
# Error messages often indicate the exact line number where the error occurred, which helps you pinpoint and fix the issue.
#
# </details>

# %% [markdown]
# **6️⃣ What is the recommended approach to practice and improve your Python skills?**
#
# a) Rely on theoretical knowledge without practical practice.
# b) Avoid coding challenges and real-world projects.
# c) Regularly work on coding exercises, projects, and challenges.
# d) Practice only when encountering problems.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Regularly work on coding exercises, projects, and challenges.**
#
# 💡 **Explanation:**
# The recommended approach to practice and improve your Python skills is to regularly work on coding exercises, projects, and challenges.
#
# </details>

# %% [markdown]
# **7️⃣ Which type of error is present in the following code snippet?**
#
# ```python
# print((1, 2, 3)
# ```
#
# a) SyntaxError
# b) IndentationError
# c) NameError
# d) TypeError
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **SyntaxError**
#
# 💡 **Explanation:**
# The code is missing a closing parenthesis `)` after the number `3`.
# This results in a SyntaxError because the code does not follow the correct syntax of a print statement.
#
# </details>

# %% [markdown]
# **8️⃣ Which type of error is present in the following code snippet?**
#
# ```python
# for i in range(5):
# print(i)
# ```
#
# a) SyntaxError
# b) IndentationError
# c) NameError
# d) TypeError
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **IndentationError**
#
# 💡 **Explanation:**
# The code lacks proper indentation for the line inside the `for` loop.
# Python requires consistent indentation to define code blocks.
# The lack of indentation in this case leads to an IndentationError.
#
# </details>

# %% [markdown]
# **9️⃣ Which type of error is present in the following code snippet?**
#
# ```python
# x = 10
# z = x + y
# ```
#
# a) SyntaxError
# b) IndentationError
# c) TypeError
# d) NameError
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **NameError**
#
# 💡 **Explanation:**
# The variable `y` is used in the calculation of `z`, but it has not been defined previously.
# This leads to a NameError since Python doesn't recognize the variable `y`.
#
# </details>

# %% [markdown]
# **1️⃣0️⃣ Which type of error is present in the following code snippet?**
#
# ```python
# result = "42" + 7
# ```
#
# a) SyntaxError
# b) IndentationError
# c) TypeError
# d) NameError
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **TypeError**
#
# 💡 **Explanation:**
# In this code, you are trying to concatenate a string `"42"` with an integer `7`.
# This operation results in a TypeError because Python does not allow concatenating different data types directly.
#
# </details>
