# %% [markdown]
# # Quiz: Project Directories in Python

# %% [markdown]
# **1️⃣ Which directory in a Python project typically houses the main application code? (Select all that apply)**
#
# a) assets
# b) utils
# c) app
# d) src
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **app**, d) **src**
#
# 💡 **Explanation:**
# The **src** or **app** directory is where the main application code resides. It contains the **core logic, models, and application-specific modules**.
#
# </details>

# %% [markdown]
# **2️⃣ Which directory in a Python project is used to store static files like images, CSS, and JavaScript?**
#
# a) src
# b) assets
# c) utils
# d) tests
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **assets**
#
# 💡 **Explanation:**
# The **assets** directory is used to store static files such as **images, CSS stylesheets, and client-side JavaScript files**.
#
# </details>

# %% [markdown]
# **3️⃣ In which directory of a Python project would you typically find utility functions and classes that are used across the project?**
#
# a) utils
# b) src
# c) assets
# d) tests
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **utils**
#
# 💡 **Explanation:**
# The **utils** directory contains **utility functions and classes** that are commonly used across the project, such as **date formatting, file handling, and custom exceptions**.
#
# </details>

# %% [markdown]
# **4️⃣ Which directory in a Python project is dedicated to storing unit tests, integration tests, and end-to-end tests?**
#
# a) src
# b) assets
# c) utils
# d) tests
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **tests**
#
# 💡 **Explanation:**
# The **tests** directory is where you would find **unit tests, integration tests, and end-to-end tests** for your Python project.
#
# </details>

# %% [markdown]
# **5️⃣ Where would you typically find project documentation in a Python project?**
#
# a) src
# b) assets
# c) docs
# d) utils
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **docs**
#
# 💡 **Explanation:**
# The **docs** directory is used to store **project documentation**, which can be created using tools like **Sphinx, Doxygen, or simple Markdown files**.
#
# </details>

# %% [markdown]
# **6️⃣ In which directory of a Python project would you find configuration files such as .env or settings.py?**
#
# a) src
# b) config
# c) assets
# d) utils
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **config**
#
# 💡 **Explanation:**
# The **config** directory is where you would store **configuration files** like **.env** or **settings.py**, which contain settings for **databases, API keys, and environment-specific configurations**.
#
# </details>

# %% [markdown]
# **7️⃣ Which directory in a Python project is dedicated to build scripts, data migration scripts, and other automation scripts?**
#
# a) scripts
# b) src
# c) assets
# d) utils
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **scripts**
#
# 💡 **Explanation:**
# The **scripts** directory is used to store **build scripts, data migration scripts, and other automation scripts** that help automate tasks within the project.
#
# </details>

# %% [markdown]
# **8️⃣ Where would you typically store data files like CSV, JSON, or XML in a Python project?**
#
# a) src
# b) config
# c) utils
# d) data
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **data**
#
# 💡 **Explanation:**
# The **data** directory is used to store **data files** such as **CSV, JSON, or XML**. These files may contain **sample data, test data, or configuration data**.
#
# </details>

# %% [markdown]
# **9️⃣ Which directory is commonly used in web applications to store database migration files?**
#
# a) public
# b) migrations
# c) templates
# d) data
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **migrations**
#
# 💡 **Explanation:**
# The **migrations** directory is commonly used in web applications to store **database migration files**, which handle **schema changes and data migrations**.
#
# </details>

# %% [markdown]
# **🔟 Which directory is typically used in web applications to house publicly accessible files like images, CSS, and JavaScript? (Select all that apply)**
#
# a) static
# b) public
# c) templates
# d) data
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **static**, b) **public**
#
# 💡 **Explanation:**
# The **public** or **static** directory in web applications is used to store **publicly accessible files** such as **images, CSS stylesheets, and JavaScript files**.
#
# </details>
