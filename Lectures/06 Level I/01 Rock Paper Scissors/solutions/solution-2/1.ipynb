# %% [markdown]
# توی ریدمی شروع به نوشتن دیسکریپشنی از کد میکنیم وقتی که تموم شد یعنی تا موقعی که پروژه تموم نشده نیازی نیست وارد ریدمی بشی

# %% [markdown]
# وقتی میخوای کد بزنی توی پایتون دوتا سلوشن پیش روی ما هست برای تست و دیباگینگ و محیطی که میخوای داخل اون کد بزنی یکی فایل دات پای و یکی جوپیتور نوت بوک هستش.

# %% [markdown]
# فایل های جوپیتر برای تست کردن خیلی خوبن چون در واقع repl اند
# read
# evaluation
# print
# loop
# معمولا اول با این شروع میکنیم و بعد سلوشن رو میبریم توی فایل دات پای که یک نفر بتونه از بالا تا پایین این اسکریپت رو ران بکنه و فلدر های مختلف و کارای مختلف.

# %% [markdown]
# ‌بعضی جاها فایل های دات‌‌‌ پای بهتره و بعضی جاها ام جوپیتر
# وقتی با جنگو، تنسور فلو،  و فست ای پی آی استفاده میکنی باید کار با این فایل های دات پای رو بیشتر یاد بگیری و فقط محدود به جوپیتر نشی

# %% [markdown]
# برای بعضی از پروژه ها نیاز هست که بیای ریدمی رو هعی بخونی اما برای این نیاز نیست چون سادست

# %% [markdown]
# سرکار مدام باید فیدبک بدید و در تماس باشید و اینطور نباشه که برید یک چیزی رو از کارفرما بگیرید و برید دو ماه بعد بیاید، توی واقعی توی استپ های مختلف باید ببینی آیا داری مسیر رو درست میری و فیدبک بدید و سینک بشید با اون کسی که این کار رو به ما سپرده
# عادت کنید به رفت و برگشت های متوالی، نرید یک گوشه بشینید برای خودتون دوماه کار کنید، کمینیت و ارتباط گرفتن رو درک بکنید

# %% [markdown]
# اولش همیشه که شروع میکنید سعی کنید یک پلنینگی داشته باشید هرچند که پروژه راحت باشه

# %% [markdown]
# پلنینگ یعنی چی؟ مثلا وقتی قراره این بازی رو بنویسیم:
# اول باید با چه سلشنی شروع کنم؟ OOP or Functional?
# کدوم بهتره

# %%
def rock_paper_scissor():
    pass
class RockPaperScissors:
    pass

# %% [markdown]
# اینجا چرا داریم کلاس رو به فانکشن ترجیح میدم و اینجوری با کلاس پیش میرم؟
# . تجربه از دیدن پترن های مختلف
# . سافتور دیزان
# ترکیب این دوتا به ما کمک میکنه تا در نهایت تصمیم بگیریم که پروژه رو چطوری پیش ببریم
# ساختار این برنامه بیشتر به کلاس میخوره

# %%
class RockPaperScissors:
    pass

# %% [markdown]
# پلنینگ چیه؟
# کلاس ما چه چیزهایی باید داشته باشه؟ اصلا استپ های یک بازی سنگ کاغذ غیچی چی هست؟
# اول ما یک بازیکن داریم و یک کامپیوتر

# %% [markdown]
# - get player choice
# - get computer choice
# - get winner
# - print winner
# - play again?

# %% [markdown]
# از این مراحل کد ما تشکیل شده
# حالا این رو بیارید توی این کلاسی که قراره بنویسیم
# اگر این مراحل وجود داره، این کلاس چه شکلی میشه
# واضح هست که یکسری متد ها داریم، یعنی اصلا لازم نیست شروع بکنیم به کد زدن از بیس میتونیم کامنت تور یا همینجوری برای خودمون بنویسیم

# %%
class RockPaperScissors:
    # get_player_choice(method)
    # get_computer_choice(method)
    # decide_winner(method)(it takes the aboves methods and then identify which one is the winner)
    # play(method)(it takes user's choice then the computer choice then identify which one is winner then print.)
    pass

# %% [markdown]
# این کار رو کردیم تا پروسه‌ی ذهنی خوب طبقه بندی بشه
# این کار ها حتی توی پروژه کوچیک که عادت بکنیم که وقتی به پروژه بزرگ رسیدیم نریم داخل کد تق تق کد زدن
# ۹۰-۸۰ درصد کد زدن
# اون پلنینگ و فکر کردن و دیباگینگ هستش نه اینکه فقط بخواید تایپ کنید
# مثلا حتی کد یک پروژه بزرگ چندتا فایل هستش؟ مثلا تایپ کردن ۱۰ تا فایل ۲۰ تا فایل توی نیم ساعت زمان میبره اما یک پروژه ای به اون عظمت مثلا اگه بخوایم ۱۰ تا ماژول مختلف باشه شاید یک هفته بسته به اون لاجیکش یا حتی شاید دو هفته یک ماه یا حتی یک سال طول بکشه
# دنبال تایپ کردن بیخود نباشید دنبال پلنینگ درست و در نهایت اگزکیوشن درست برای پلن باشید

# %% [markdown]
# همیشه یادتون باشه که زیاد تست بکنید، مثلا این کدی که قراره بنویسیم رو تک تک مراحلشو به ترتیب هعی تست بکنید

# %% [markdown]
# قاعدتا برای هر کلاس یک اینیت مینویسیم که توی اینیت اینشلیازیشن های که بخوایم رو باید انجام بدیم

# %%
class RockPaperScissors:
    def __init__(self, name):
        self.choices = ['rock', 'paper', 'scissors']
        self.player_name = name
