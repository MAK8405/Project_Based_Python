# %% [markdown]
# A script = a file
# src = directory with multiple files, but files(modules) are actually separated and we have more files too.
# src = we put code's file in src
# Directory with multiple modules, all of its code goes to src in Package structure with src

# %% [markdown]
# code files will go into src and we would have extra files too
# mid-range project is implemented with src structure

# %% [markdown]
# # Start writing
#
# 1. first we create a folder named "src"
#    our code will be in the "src folder", all the things is related to running the code.
#    beside src we will have the README.md file next to it.
#
# - in future project we will a lot of file or folders which are along src
#
# README.md -> من را بخوان:
#
# - markdown format
# - explain our code
# - how to run
#
# a simple way to write it:
#
# 1. First we would have the title of the project:
#
# - `# Number Guesser Game Project`
#
# 2. The description of the project:
#
# - ```## Description```
# - ``` This project is a game where users...```
#
# we add different parts in this way.
#
# 3. ```## How to Run```
# - Clone ...
# - Run ...
# - Run ...

# %% [markdown]
# In src we always have main.py for our main code. and we use other packages that we make in src. like utils(functionally through whole project)
# game_logic ->
# all of the logic
# generates score
# giving hint
# write congratulation
# generate number
# assets -> file needed for running project, images, text files, dataset or we can put dataset in data folder
# these different folders have a role of package and and we will import them in main.py or we put a file then read from on it.

# %% [markdown]
# then we start writing on main.py like a single script
# It's like single script, but not all of the code will go into main.py
# it goes to other packages

# %% [markdown]
# How we run it?
# we add the path of the directory that includes src,
# Python pass = a list of directory that python goes to them and search for them so to find a module

# %%
import sys

sys.path
# Out:
# ['c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310',
#  '',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages']

# %% [markdown]
# each import we type, it goes in order to the upward directory to find them. if they find it, it stops, not find => continue till the end, if not found it says module not found.
# To run this project:
# we should write
# src/main.py in terminal

# %% [markdown]
# There is a bit tricky when we want to import from our packages in src.

# %% [markdown]
# It's good to test the function when we write it for every function write away after testing.

# %%
# For example:
if __name__ == "__main__":
    print(get_valid_input(1, 10))

# %% [markdown]
# He recommends when we write a thing like utils and we put some functionality on it, before using it in any module or scripts, test them to see if they are showing the proper behavior or not.
# we can test it like the code above or in ipynb (we create this file in the same directory as utils) then we do it like below

# %%
from iput_validator import get_valid_input

print(get_valid_input(1, 10))
# This way is like writing test cases.
# We wrote a test case
# If the testing in terminal is hard for you, you can test in ipynb
# There are as many ways to write test cases as there are people.

# %% [markdown]
# > How we write imports in src structure?
# > we import all of them from source, in this way we are sure that everything will be start from a point. and we won't have problem, like have a unix route.
# > in linux we type cd/ to go to the root directory, here we do the same, we start from src
# > from src.utils import ...
# > like:
#
# ```python
# from src.utils import get_valid_input
#
# def main():
#     user_input = get_valid_input(1,100)
#     print(user_input)
#
# ```

# %% [markdown]
# How we run it?
# We should go to where we are running project, we cd to that, like number_guesser.
# here the path of src should go to system path(Python path(the path that python goes to them to find packages))
# we should add the directory that src is in it to python path
# we do it with export(set environment variable) like this:
# export PYTHONPATH=$PYTHONPATH:$(pwd)
# it tells that the setting up the python path variable is like setting variable in Python
# like:
# متغیر پایتون پس مساوی بشه با متغییری که قبلا بوده بعلاوه کارنت درکتوری
# like:
# x += 1

# %% [markdown]
# ```bash
# export PYTHONPATH=$PYTHONPATH:$(pwd)
# echo $PYTHONPATH # with echo $ we can see the variable that we have set (Linux things)
# ```
# The path that it will search for we'll be separate with ":"

# %% [markdown]
# we run the project with
# ```bash
# python src/main.py

# %% [markdown]
# > We should learn that we should structure the project, run it, and understand it without memorizing it

# %% [markdown]
# every import that we should want from our packages should start from src
#
# ```python
# from src.modules/packages import ...
# ```

# %% [markdown]
# src is overkill for this project since it's small, but it's good to learn how to structure the project for future or larger projects

# %% [markdown]
# modular -> if in a time our logic of our code gets too complex, like the hint, or the random number, or the score comes to a complex system, therefore this structure can easily be scaled, we can easily add folders or packages and organize files in a neatly way. not just a simple file with 10,000 lines of code.
# a code should be broken down to smaller parts, so it's easier to read, maintain, and test.
# not always breaking down a code is a good idea, since breaking it down to different parts, following the code is hard, for example for debugging, we should jump between different files to find the problem. in simple script with just one eye in a sequence way (posht ham) we see.
# splitting and abstracting is not always perfect and always everything it has is a merit.
# When abstractions occurred, when a layer of code goes to somewhere else. debugging is harder
# each merits has its own merits and drawbacks. depending on our work we choose a paradigm.
# All of the Python based on OOP which means a prime paradigm template is OOP.

# %% [markdown]
# تا جایی که میشه وقتی میخوای کدت رو خودت بزنی تق تق نگاه نکن و فکر کن و خودت بنویس تا مغز بیشتر کار بکنه و وقتی به کار افتاد و کامل راه افتاد و تسلط پیدا کردی از ابزار های دیگه استفاده کن.

# %% [markdown]
# along src folder we can have different files too.
