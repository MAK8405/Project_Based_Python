# %% [markdown]
# # Quiz: Download Pytopia Courses Source Code

# %% [markdown]
# **1️⃣ Which method can be used to download a repository as a ZIP file?**
#
# a) Using Git
# b) Navigating to the repository, clicking on the "Code" button, and selecting "Download ZIP"
# c) Using the Command Line
# d) Using a Package Manager
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Navigating to the repository, clicking on the "Code" button, and selecting "Download ZIP"**
#
# 💡 **Explanation:**
# The correct method to download a repository as a ZIP file is by using the download button. This involves navigating to the repository, clicking on the Code button, and selecting Download ZIP to save the repository contents as a compressed ZIP file.
#
# </details>

# %% [markdown]
# **2️⃣ What is the recommended approach to update the content of a repository that you previously downloaded as a ZIP file?**
#
# a) Manually rewrite the code in the repository to match the latest version.
# b) Using git pull command to update the content.
# c) Download the updated ZIP file from the repository's source and replace the existing content.
# d) Create a new repository and copy the code from the old repository.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Download the updated ZIP file from the repository's source and replace the existing content.**
#
# 💡 **Explanation:**
# The recommended approach to update the content of a repository that you previously downloaded as a ZIP file is to download the updated ZIP file from the repository's source and replace the existing content. This ensures that you have the latest version of the repository's content without losing any changes you made locally.
#
# </details>

# %% [markdown]
# **3️⃣ What is the purpose of the git clone command?**
#
# a) To create a new repository.
# b) To compress the repository files.
# c) To update the local repository with the latest changes.
# d) To copy the remote repository to the local machine.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **To copy the remote repository to the local machine.**
#
# 💡 **Explanation:**
# The `git clone` command is used to copy the remote repository from an online source (like GitHub) to the local machine. It creates a local copy of the repository for further development and collaboration.
#
# </details>

# %% [markdown]
# **4️⃣ What is the purpose of the git pull command in Git?**
#
# a) To push local changes to the remote repository.
# b) To merge changes from the remote repository into the local repository.
# c) To create a new branch in the local repository.
# d) To clone a new repository from a remote source.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **To merge changes from the remote repository into the local repository.**
#
# 💡 **Explanation:**
# The `git pull` command is used to merge changes from the remote repository into the local repository. It fetches the latest changes from the remote repository and automatically incorporates them into your current local branch.
#
# </details>
