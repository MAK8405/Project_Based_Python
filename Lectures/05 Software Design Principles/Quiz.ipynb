# %% [markdown]
# **1️⃣ Which of the following is not a SOLID principle?**
#
# a) Single Responsibility Principle (SRP)
# b) Open-Closed Principle (OCP)
# c) Uniform Resource Locator (URL)
# d) Liskov Substitution Principle (LSP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Uniform Resource Locator (URL)
#
# 💡 **Explanation:**
# The SOLID principles are a set of software design principles aimed at making software more maintainable and flexible. URL is not a part of SOLID principles.
#
# </details>

# %% [markdown]
# **2️⃣ According to the Single Responsibility Principle (SRP), a class should have:**
#
# a) Only one method
# b) Only one responsibility
# c) Only one instance variableOnly one constructor
# d) Only one constructor
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Only one responsibility
#
# 💡 **Explanation:**
# The SRP states that a class should have only one reason to change, meaning it should have only one responsibility or concern.
#
# </details>

# %% [markdown]
# **3️⃣ Which SOLID principle states that "software entities should be open for extension but closed for modification"?**
#
# a) Single Responsibility Principle (SRP)
# b) Liskov Substitution Principle (LSP)
# c) Interface Segregation Principle (ISP)
# d) Open-Closed Principle (OCP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Open-Closed Principle (OCP)
#
# 💡 **Explanation:**
# The OCP states that software entities (classes, modules, functions) should be open for extension (allowing new functionality to be added) but closed for modification (existing code should not be modified).
#
# </details>

# %% [markdown]
# **4️⃣ The Liskov Substitution Principle (LSP) states that:**
#
# a) Subtypes must be substitutable for their base types
# b) Subtypes must override all methods of their base types
# c) Subtypes must be marked as abstract classes
# d) Subtypes must have the same number of methods as their base types
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Subtypes must be substitutable for their base types
#
# 💡 **Explanation:**
# The LSP states that objects of a superclass should be replaceable with objects of its subclasses without affecting the correctness of the program.
#
# </details>

# %% [markdown]
# **5️⃣ Which SOLID principle focuses on the segregation of interfaces to prevent clients from depending on unnecessary methods?**
#
# a) Single Responsibility Principle (SRP)
# b) Open-Closed Principle (OCP)
# c) Liskov Substitution Principle (LSP)
# d) Interface Segregation Principle (ISP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Interface Segregation Principle (ISP)
#
# 💡 **Explanation:**
# The ISP states that clients should not be forced to depend on interfaces they do not use. It promotes the idea of smaller, focused interfaces instead of large, monolithic interfaces.
#
# </details>

# %% [markdown]
# **6️⃣ Which SOLID principle emphasizes that dependency should be on abstractions, not on concrete implementations?**
#
# a) Single Responsibility Principle (SRP)
# b) Dependency Inversion Principle (DIP)
# c) Open-Closed Principle (OCP)
# d) Liskov Substitution Principle (LSP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Dependency Inversion Principle (DIP)
#
# 💡 **Explanation:**
# The DIP states that high-level modules should not depend on low-level modules. Instead, both should depend on abstractions. It promotes loose coupling between modules.
#
# </details>

# %% [markdown]
# **7️⃣ Which SOLID principle suggests that a class should have only one reason to change?**
#
# a) Open-Closed Principle (OCP)
# b) Liskov Substitution Principle (LSP)
# c) Single Responsibility Principle (SRP)
# d) Interface Segregation Principle (ISP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Single Responsibility Principle (SRP)
#
# 💡 **Explanation:**
# The SRP states that a class should have only one responsibility or reason to change. This principle promotes code that is easier to understand and maintain.
#
# </details>

# %% [markdown]
# **8️⃣ Which principle can be violated if a subclass does not implement all the methods of its base class?**
#
# a) Single Responsibility Principle (SRP)
# b) Open-Closed Principle (OCP)
# c) Liskov Substitution Principle (LSP)
# d) Interface Segregation Principle (ISP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Liskov Substitution Principle (LSP)
#
# 💡 **Explanation:**
# The LSP states that objects of a superclass should be substitutable with objects of its subclasses. If a subclass does not implement all the methods of its base class, it violates this principle.
#
# </details>

# %% [markdown]
# **9️⃣ Which SOLID principle promotes the idea of smaller and focused interfaces?**
#
# a) Single Responsibility Principle (SRP)
# b) Open-Closed Principle (OCP)
# c) Liskov Substitution Principle (LSP)
# d) Interface Segregation Principle (ISP)
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** Interface Segregation Principle (ISP)
#
# 💡 **Explanation:**
# The ISP suggests that interfaces should be segregated into smaller and more focused interfaces to prevent clients from depending on unnecessary methods.
#
# </details>

# %% [markdown]
# **🔟 In Python, which built-in module provides support for abstract classes and interfaces?**
#
# a) abc
# b) math
# c) functools
# d) collections
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** abc
#
# 💡 **Explanation:**
# The abc (abstract base class) module in Python provides support for defining abstract base classes and interfaces.
#
# </details>
