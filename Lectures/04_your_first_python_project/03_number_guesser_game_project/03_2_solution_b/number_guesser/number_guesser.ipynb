# %% [markdown]
# A script = a file
# src = directory with multiple files, but files(modules) are actually separated and we have more files too.
# src = we put code's file in src
# Directory with multiple modules, all of its code goes to src in Package structure with src

# %% [markdown]
# code files will go into src and we would have extra files too
# mid-range project is implemented with src structure

# %% [markdown]
# # Start writing
#
# 1. first we create a folder named "src"
#    our code will be in the "src folder", all the things is related to running the code.
#    beside src we will have the README.md file next to it.
#
# - in future project we will a lot of file or folders which are along src
#
# README.md -> من را بخوان:
#
# - markdown format
# - explain our code
# - how to run
#
# a simple way to write it:
#
# 1. First we would have the title of the project:
#
# - `# Number Guesser Game Project`
#
# 2. The description of the project:
#
# - ```## Description```
# - ``` This project is a game where users...```
#
# we add different parts in this way.
#
# 3. ```## How to Run```
# - Clone ...
# - Run ...
# - Run ...

# %% [markdown]
# In src we always have main.py for our main code. and we use other packages that we make in src. like utils(functionally through whole project)
# game_logic ->
# all of the logic
# generates score
# giving hint
# write congratulation
# generate number
# assets -> file needed for running project, images, text files, dataset or we can put dataset in data folder
# these different folders have a role of package and and we will import them in main.py or we put a file then read from on it.

# %% [markdown]
# then we start writing on main.py like a single script
# It's like single script, but not all of the code will go into main.py
# it goes to other packages

# %% [markdown]
# How we run it?
# we add the path of the directory that includes src,
# Python pass = a list of directory that python goes to them and search for them so to find a module

# %%
import sys

sys.path
# Out:
# ['c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310',
#  '',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib',
#  'C:\\Users\\Sepehr\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin',
#  'c:\\Users\\Sepehr\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages']

# %% [markdown]
# each import we type, it goes in order to the upward directory to find them. if they find it, it stops, not find => continue till the end, if not found it says module not found.
