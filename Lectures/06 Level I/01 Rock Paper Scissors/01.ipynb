# %% [markdown]
# برای هر سلوشن یک فایل ریدمی داشته باشه

# %% [markdown]
# توی تمام پروژه ها مسیر این شکلی هست که وارد پروژه میشید،‌ریدمیش رو میخونید، و ایده میگیرید که پروژه چه شکلی باید باشه، بعدش یک پلن انجام میدید و برحسب اون پلن کم کم کد رو دولپ میکنیم و یک کدی در نهایت حاصل میشه و تستش میکنیم ببینیم که ران میشه یا نمیشه و در نهایت که نهایی شد یک فایل ریدمی برای سلوشنتون ایجاد میکنید.
