# %% [markdown]
# ## Quiz 1: Python Essential Concepts

# %% [markdown]
# **1️⃣ What are variables used for in Python?**
#
# a) To perform mathematical operations.
# b) To store and manipulate data.
# c) To define classes and objects.
# d) To import external modules.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **To store and manipulate data.**
#
# 💡 **Explanation:**
# Variables in Python are used to store and manipulate data.
# They allow you to store values of various data types and use them in your code.
#
# </details>

# %% [markdown]
# **2️⃣ What is the primary distinction between variables and data types in Python?**
#
# a) Variables determine the operations that can be performed on data, while data types store values.
# b) Variables store values, while data types specify the type of values that can be stored.
# c) Variables are used to define functions, while data types are used to define classes.
# d) Variables store only integers, while data types store floating-point numbers.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Variables store values, while data types specify the type of values that can be stored.**
#
# </details>

# %% [markdown]
# **3️⃣ Which of the following is NOT a Python data type?**
#
# a) int
# b) str
# c) func
# d) float
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **func**
#
# 💡 **Explanation:**
# `func` is not a Python data type.
#
# </details>

# %% [markdown]
# **4️⃣ What is the meaning of expressions in Python?**
#
# a) Expressions are a way to define functions in Python.
# b) Expressions are used to represent comments and documentation within Python code.
# c) Expressions are combinations of values, variables, operators, and function calls that produce a result.
# d) Expressions are reserved keywords in Python used for controlling the flow of execution.
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Expressions are combinations of values, variables, operators, and function calls that produce a result.**
#
# </details>

# %% [markdown]
# **5️⃣ Which of the following options does NOT correctly match the type of Python operator with its example?**
#
# a) Comparison operator: >=
# b) Arithmetic operator: //
# c) Logical operator: not
# d) Assignment operator: ==
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** d) **Assignment operator: ==**
#
# 💡 **Explanation:**
# The `==` operator is a **comparison operator**, while the `=` operator is the **assignment operator**.
#
# </details>

# %% [markdown]
# **6️⃣ Which of the following is NOT typically categorized as a traditional logical operator, but it does serve a similar purpose of making comparisons?**
#
# a) is
# b) and
# c) not
# d) or
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **is**
#
# 💡 **Explanation:**
# `is` is a reserved keyword in Python and it isn't a traditional logical operator,
# but it does serve a similar purpose of making comparisons.
#
# </details>

# %% [markdown]
# **7️⃣ Which of the following is considered as a control flow construct in Python? (more than one answer is true)**
#
# a) String manipulation
# b) Conditional statements
# c) List comprehension
# d) for loops and while loops
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Conditional statements**, d) **for loops and while loops**
#
# 💡 **Explanation:**
# **Conditional statements** and **loops** are considered as a control flow in Python.
#
# </details>

# %% [markdown]
# **8️⃣ Which pair of choices can complete the following statement?**
#
# "____ loop is used for iterating over a sequence of elements, and ____ loop is used for executing a block of code as long as a condition is true."
#
# a) for - while
# b) while - for
# c) if - for
# d) repeat - while
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **for - while**
#
# 💡 **Explanation:**
# A **for** loop is used to iterate over a sequence of elements,
# while a **while** loop executes as long as a given condition remains true.
#
# </details>

# %% [markdown]
# **7️⃣ Which of the following is considered as a control flow construct in Python?**
# *(More than one answer is true)*
#
# a) String manipulation
# b) Conditional statements
# c) List comprehension
# d) for loops and while loops
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** b) **Conditional statements**, d) **for loops and while loops**
#
# 💡 **Explanation:**
# Conditional statements and loops are considered control flow constructs in Python.
#
# </details>

# %% [markdown]
# **8️⃣ Which pair of choices can complete the following statement?**
#
# *"____ loop is used for iterating over a sequence of elements, and ____ loop is used for executing a block of code as long as a condition is true."*
#
# a) for - while
# b) while - for
# c) if - for
# d) repeat - while
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **for - while**
#
# 💡 **Explanation:**
# `for` loop is used for iterating over a sequence of elements,
# and `while` loop is used for executing a block of code as long as a condition is true.
#
# </details>

# %% [markdown]
# **9️⃣ Which of the following are reusable blocks of code that perform specific tasks in Python?**
#
# a) Strings
# b) Lists
# c) Functions
# d) Operators
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** c) **Functions**
#
# 💡 **Explanation:**
# Functions are reusable blocks of code that perform specific tasks in Python.
#
# </details>

# %% [markdown]
# **1️⃣0️⃣ Which of the following is a programming paradigm that allows you to define classes, which are blueprints for creating objects?**
#
# a) Object-Oriented Programming (OOP)
# b) Functional Programming (FP)
# c) Procedural Programming
# d) Logical Programming
#
# ---
#
# <details>
#   <summary>✅ Show Answer</summary>
#
# **Answer:** a) **Object-Oriented Programming (OOP)**
#
# 💡 **Explanation:**
# Object-Oriented Programming (OOP) is a programming paradigm that allows you to define classes, which are blueprints for creating objects.
#
# </details>
